# %% [markdown]
# # Task 1: Using RLTK to perform Entity Resolution (ER)
#
# <sub>Content of this notebook was prepared by Basel Shbita, and modified by Avijit Thawani (thawani@usc.edu) as part of the class <u>DSCI 558: Building Knowledge Graphs</u> at University of Southern California (USC).</sub>

# %% [markdown]
# The Record Linkage ToolKit ([RLTK](https://github.com/usc-isi-i2/rltk)) is a general-purpose open-source record linkage platform that allows users to build powerful Python programs that link records referring to the same underlying entity.
#
# This notebook introduces some applied examples using RLTK. You can also find additional examples and use-cases in [RLTK's documentation](https://rltk.readthedocs.io/en/master/).

# %% [markdown]
# ## Dataset analysis & RLTK components construction

# %% [markdown]
# First, you need define how a single entry would like for each type of record (for each dataset)

# %%
import rltk
import json
import csv
import pandas as pd
from difflib import SequenceMatcher

# %%
tokenizer = rltk.tokenizer.crf_tokenizer.crf_tokenizer.CrfTokenizer()

# %%
usnews = pd.read_csv("python/usnews.csv")
usnews.rename(columns={'Unnamed: 0':'ID'}, inplace=True)
gradcafe = pd.read_csv("gradcafe.csv")

# %%
usnews
# Out:
#       ID                                   name  \
# 0      0                   Princeton University
# 1      1                    Columbia University
# 2      2                     Harvard University
# 3      3  Massachusetts Institute of Technology
# 4      4                        Yale University
# ..   ...                                    ...
# 145  145              University of the Pacific
# 146  146                    University of Tulsa
# 147  147              Colorado State University
# 148  148                     CUNY--City College
# 149  149                    Duquesne University
#
#                                                    url          location  \
# 0    https://www.usnews.com//best-colleges/princeto...     Princeton, NJ
# 1    https://www.usnews.com//best-colleges/columbia...      New York, NY
# 2    https://www.usnews.com//best-colleges/harvard-...     Cambridge, MA
# 3    https://www.usnews.com//best-colleges/massachu...     Cambridge, MA
# 4    https://www.usnews.com//best-colleges/yale-uni...     New Haven, CT
# ..                                                 ...               ...
# 145  https://www.usnews.com//best-colleges/universi...      Stockton, CA
# 146  https://www.usnews.com//best-colleges/universi...         Tulsa, OK
# 147  https://www.usnews.com//best-colleges/colorado...  Fort Collins, CO
# 148  https://www.usnews.com//best-colleges/cuny-cit...      New York, NY
# 149  https://www.usnews.com//best-colleges/duquesne...    Pittsburgh, PA
#
#     no. of reviews                                        description  \
# 0       19 reviews  The ivy-covered campus of Princeton University...
# 1       39 reviews  Columbia University has three undergraduate sc...
# 2       17 reviews  Harvard University is a private institution in...
# 3       12 reviews  Though the Massachusetts Institute of Technolo...
# 4       10 reviews  Yale University, located in New Haven, Connect...
# ..             ...                                                ...
# 145      4 reviews  The University of the Pacific is a private col...
# 146      6 reviews  Students at the University of Tulsa leave with...
# 147      6 reviews  Colorado State University, also known as CSU, ...
# 148      3 reviews  Founded in 1847, CUNY--City College is a publi...
# 149      3 reviews  Founded in 1878, Duquesne University is a priv...
#
#                    tuition         enrollment
# 0                 $56,010    4,773(fall 2020)
# 1                 $63,530    6,170(fall 2020)
# 2                 $55,587    5,222(fall 2020)
# 3                 $55,878    4,361(fall 2020)
# 4                 $59,950    4,703(fall 2020)
# ..                     ...                ...
# 145               $52,352    3,524(fall 2020)
# 146               $44,838    2,929(fall 2020)
# 147  $31,540(out-of-state)  25,186(fall 2020)
# 148  $19,010(out-of-state)  12,587(fall 2020)
# 149               $43,526    5,383(fall 2020)
#
# [150 rows x 8 columns]

# %%
gradcafe
# Out:
#           ID                                  university  \
# 0          1                   Michigan State University
# 1          2                    Johns Hopkins University
# 2          3             Stevens Institute Of Technology
# 3          4                                        UIUC
# 4          5                  Carnegie Mellon University
# ...      ...                                         ...
# 49738  49745                          Clemson University
# 49739  49746         University Of California, San Diego
# 49740  49747                  University Of Texas Austin
# 49741  49748                                    NC State
# 49742  49749  University Of California, San Diego (UCSD)
#
#                                      major   degree season  decision  \
# 0                   Mechanical Engineering      PhD    NaN  Rejected
# 1                   Mechanical Engineering      PhD    NaN  Rejected
# 2                   Mechanical Engineering      PhD    NaN  Rejected
# 3      Civil And Environmental Engineering  Masters    NaN  Accepted
# 4      Electrical And Computer Engineering      PhD    NaN  Accepted
# ...                                    ...      ...    ...       ...
# 49738                 Computer Engineering      PhD    F15  Rejected
# 49739     Computer Science And Engineering  Masters    F15  Accepted
# 49740               Mechanical Engineering      PhD    F15  Rejected
# 49741                  Nuclear Engineering      PhD    F15  Accepted
# 49742     Computer Science And Engineering  Masters    F15  Accepted
#
#       decision_method decision_date   gpa  gre_verbal  gre_quant  gre_writing  \
# 0             Website     19-Nov-21  3.63         NaN        NaN          NaN
# 1              E-mail     17-Nov-21   NaN         NaN        NaN          NaN
# 2              E-mail     16-Nov-21  3.85       156.0      161.0          4.0
# 3              E-mail      5-May-21  3.42       155.0      162.0          3.5
# 4              E-mail     11-Nov-21  3.50       151.0      166.0          3.5
# ...               ...           ...   ...         ...        ...          ...
# 49738          E-mail     29-Jan-15  3.86       147.0      167.0          3.5
# 49739          E-mail     29-Jan-15   NaN       170.0      154.0          3.0
# 49740         Website     28-Jan-15   NaN         NaN        NaN          NaN
# 49741          E-mail     29-Jan-15  3.64       162.0      164.0          4.5
# 49742          E-mail     29-Jan-15  3.52       155.0      169.0          4.5
#
#       status created_at                                            comment
# 0          I  19-Nov-21  I am rejecting without mentioning any reason I...
# 1          U  17-Nov-21  Department resubmitted my application for Fall...
# 2          I  16-Nov-21  "...We have reviewed your application for a Ph...
# 3          I  14-Nov-21  Applied for PhD but accepted for non thesis ma...
# 4          U  11-Nov-21  Oh my god. It is unbelievable.\nI am CMU MS EC...
# ...      ...        ...                                                ...
# 49738      I  29-Jan-15                                 report spam\nreply
# 49739      I  29-Jan-15  Non-CS undergrad. One paper in preparation. On...
# 49740      I  29-Jan-15  1 Journal Publication,and another close to Pub...
# 49741      A  29-Jan-15                                 report spam\nreply
# 49742      A  29-Jan-15                                 report spam\nreply
#
# [49743 rows x 15 columns]

# %%
class usnewsRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['ID']

    @rltk.cached_property
    def name_string(self):
        return self.raw_object['name']

    @rltk.cached_property
    def name_tokens(self):
        return set(tokenizer.tokenize(self.name_string))

class gradcafeRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['ID']

    @rltk.cached_property
    def name_string(self):
        return self.raw_object['university']
    
    @rltk.cached_property
    def name_tokens(self):
        return set(tokenizer.tokenize(self.name_string))

# %%
usnews_file = 'python/usnews.csv'
gradcafe_file = 'gradcafe.csv'

ds1 = rltk.Dataset(rltk.CSVReader(usnews_file),record_class=usnewsRecord)
ds2 = rltk.Dataset(rltk.CSVReader(gradcafe_file),record_class=gradcafeRecord)

df1 = ds1.generate_dataframe()
df2 = ds2.generate_dataframe()

# %% [markdown]
# You can load your json-lines files into RLTK using this method:

# %% [markdown]
# And we can inspect a few entries:

# %%
print(ds1.generate_dataframe().head(5))
# Out:
#   id                            name_string  \
# 0  0                   Princeton University
# 1  1                    Columbia University
# 2  2                     Harvard University
# 3  3  Massachusetts Institute of Technology
# 4  4                        Yale University
#
#                                   name_tokens
# 0                     {University, Princeton}
# 1                      {University, Columbia}
# 2                       {University, Harvard}
# 3  {Massachusetts, Technology, Institute, of}
# 4                          {University, Yale}

# %%
print(ds2.generate_dataframe().head(5))
# Out:
#   id                      name_string                           name_tokens
# 0  1        Michigan State University         {University, Michigan, State}
# 1  2         Johns Hopkins University          {Hopkins, Johns, University}
# 2  3  Stevens Institute Of Technology  {Of, Stevens, Technology, Institute}
# 3  4                             UIUC                                {UIUC}
# 4  5       Carnegie Mellon University        {University, Mellon, Carnegie}

# %% [markdown]
# # Blocking

# %%
bg = rltk.HashBlockGenerator()
block = bg.generate(
    bg.block(ds1, property_='name_string'),
    bg.block(ds2, property_='name_string')
)

# %% [markdown]
# ## Field (Attribute) Similarity

# %%
def name_string_similarity_1(r1, r2):
    s1 = r1.name_string.lower()
    s2 = r2.name_string.lower()
    
    return rltk.jaro_winkler_similarity(s1, s2)
    
def name_string_similarity_2(r1, r2):
    s1 = r1.name_string.lower()
    s2 = r2.name_string.lower()   
    if s1 == s2:
        return 1 
    return 0

# %% [markdown]
# ## Entity Linking

# %%
# threshold value to determine if we are confident the record match
MY_TRESH = 0.8 # this number is just an example, you need to change it

# entity linkage scoring function
def rule_based_method(r1, r2):

#     isbn_score = isbn_similarity_1(r1, r2)
    name_score_1 = name_string_similarity_1(r1, r2)
    name_score_2 = name_string_similarity_2(r1, r2)
    
    total = (name_score_1 * 0.5 + name_score_2 * 0.5)
    
    # return two values: boolean if they match or not, float to determine confidence
    return total > MY_TRESH, total

# %% [markdown]
# ## EL Evaluation

# %% [markdown]
# Evaluation is a built-in module for benchmarking. Lets load our development set

# %%
dev = pd.read_csv('dev.csv')
# test = pd.read_csv("test.csv")

# %%
gradcafe
# Out:
#           ID                                  university  \
# 0          1                   Michigan State University
# 1          2                    Johns Hopkins University
# 2          3             Stevens Institute Of Technology
# 3          4                                        UIUC
# 4          5                  Carnegie Mellon University
# ...      ...                                         ...
# 49738  49745                          Clemson University
# 49739  49746         University Of California, San Diego
# 49740  49747                  University Of Texas Austin
# 49741  49748                                    NC State
# 49742  49749  University Of California, San Diego (UCSD)
#
#                                      major   degree season  decision  \
# 0                   Mechanical Engineering      PhD    NaN  Rejected
# 1                   Mechanical Engineering      PhD    NaN  Rejected
# 2                   Mechanical Engineering      PhD    NaN  Rejected
# 3      Civil And Environmental Engineering  Masters    NaN  Accepted
# 4      Electrical And Computer Engineering      PhD    NaN  Accepted
# ...                                    ...      ...    ...       ...
# 49738                 Computer Engineering      PhD    F15  Rejected
# 49739     Computer Science And Engineering  Masters    F15  Accepted
# 49740               Mechanical Engineering      PhD    F15  Rejected
# 49741                  Nuclear Engineering      PhD    F15  Accepted
# 49742     Computer Science And Engineering  Masters    F15  Accepted
#
#       decision_method decision_date   gpa  gre_verbal  gre_quant  gre_writing  \
# 0             Website     19-Nov-21  3.63         NaN        NaN          NaN
# 1              E-mail     17-Nov-21   NaN         NaN        NaN          NaN
# 2              E-mail     16-Nov-21  3.85       156.0      161.0          4.0
# 3              E-mail      5-May-21  3.42       155.0      162.0          3.5
# 4              E-mail     11-Nov-21  3.50       151.0      166.0          3.5
# ...               ...           ...   ...         ...        ...          ...
# 49738          E-mail     29-Jan-15  3.86       147.0      167.0          3.5
# 49739          E-mail     29-Jan-15   NaN       170.0      154.0          3.0
# 49740         Website     28-Jan-15   NaN         NaN        NaN          NaN
# 49741          E-mail     29-Jan-15  3.64       162.0      164.0          4.5
# 49742          E-mail     29-Jan-15  3.52       155.0      169.0          4.5
#
#       status created_at                                            comment
# 0          I  19-Nov-21  I am rejecting without mentioning any reason I...
# 1          U  17-Nov-21  Department resubmitted my application for Fall...
# 2          I  16-Nov-21  "...We have reviewed your application for a Ph...
# 3          I  14-Nov-21  Applied for PhD but accepted for non thesis ma...
# 4          U  11-Nov-21  Oh my god. It is unbelievable.\nI am CMU MS EC...
# ...      ...        ...                                                ...
# 49738      I  29-Jan-15                                 report spam\nreply
# 49739      I  29-Jan-15  Non-CS undergrad. One paper in preparation. On...
# 49740      I  29-Jan-15  1 Journal Publication,and another close to Pub...
# 49741      A  29-Jan-15                                 report spam\nreply
# 49742      A  29-Jan-15                                 report spam\nreply
#
# [49743 rows x 15 columns]

# %%
ls = []
for i in gradcafe.iterrows():
    for j in usnews.iterrows():
        combination = [str(i[1]['ID']), str(j[1]['ID'])]
        ls.append(combination)

# %%
len(ls)
# Out:
# 7461450

# %% [markdown]
# And now build a ground truth based on the development set

# %%
gt = rltk.GroundTruth()
for row in ls:    
    r2 = ds2.get_record(row[0]) # 'ltable.ID'
    r1  = ds1.get_record(row[1]) # 'rtable.ID'
    if row[-1] == '1':
        gt.add_positive(r1.raw_object['ID'], r2.raw_object['ID'])
    else:
        gt.add_negative(r1.raw_object['ID'], r2.raw_object['ID'])
        
#gt.generate_all_negatives(ds1, ds2, range_in_gt=True)

# %% [markdown]
# Lets run some candidates using the ground-truth

# %%
trial = rltk.Trial(gt)
#candidate_pairs = rltk.get_record_pairs(ds1, ds2, ground_truth=gt)
#for r1, r2 in candidate_pairs:
for row in ls:
    r1 = ds1.get_record(row[1]) # 'ltable.ID'
    r2  = ds2.get_record(row[0]) # 'rtable.ID'
    result, confidence = rule_based_method(r1, r2)
    trial.add_result(r1, r2, result, confidence)

# %% [markdown]
# ### Save Test predictions
# You will be evaluated on dev and test predictions, over a hidden ground truth.

# %%
test = [row for row in ls][1:]
print(test[:2])
# Out:
# [['1', '1'], ['1', '2']]

# %%
predictions = []
for id1, id2 in test: 
    r1 = ds1.get_record(id2) # 'ltable.ID' us news
    r2  = ds2.get_record(id1) # 'rtable.ID' grad cafe
    result, confidence = rule_based_method(r1, r2)
    predictions.append((r1.id, r2.id, result, confidence))

# %%
len(predictions), len(ds1.generate_dataframe()), len(ds2.generate_dataframe())
# Out:
# (7461449, 150, 49743)

# %%
with open('Saurabh_Jain_predictions.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for row in predictions:
        writer.writerow(row)
